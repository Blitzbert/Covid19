# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("rawdata.csv")

# %%
df.groupby("female_smokers").count()
# Out:
#                 iso_code  continent  location  date  total_cases  new_cases  \
# female_smokers
# 0.1                  385        385       385   385          385        385
# 0.2                  804        804       804   804          804        804
# 0.3                 1233       1233      1233  1233         1233       1233
# 0.4                 1129       1129      1129  1129         1126       1126
# 0.5                  410        410       410   410          410        410
# ...                  ...        ...       ...   ...          ...        ...
# 34.2                 411        411       411   411          411        411
# 34.3                 409        409       409   409          409        409
# 35.3                 412        412       412   412          408        408
# 37.7                 408        408       408   408          399        399
# 44.0                 388        388       388   388          388        388
#
# ...

# %% [markdown]
# # Data for Germany

# %%
## Data for Germany
data_ger = df[df["iso_code"] == "DEU"]

# %%
data_ger
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 27849      DEU    Europe  Germany  2020-01-27          1.0        1.0
# 27850      DEU    Europe  Germany  2020-01-28          4.0        3.0
# 27851      DEU    Europe  Germany  2020-01-29          4.0        0.0
# 27852      DEU    Europe  Germany  2020-01-30          4.0        0.0
# 27853      DEU    Europe  Germany  2020-01-31          5.0        1.0
# ...        ...       ...      ...         ...          ...        ...
# 28282      DEU    Europe  Germany  2021-04-04    2896329.0    10300.0
# 28283      DEU    Europe  Germany  2021-04-05    2902309.0     5980.0
# 28284      DEU    Europe  Germany  2021-04-06    2909902.0     7593.0
# 28285      DEU    Europe  Germany  2021-04-07    2940279.0    30377.0
# 28286      DEU    Europe  Germany  2021-04-08    2966789.0    26510.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
data_ger.loc[27849:27853, ["date"]]
# Out:
#              date
# 27849  2020-01-27
# 27850  2020-01-28
# 27851  2020-01-29
# 27852  2020-01-30
# 27853  2020-01-31

# %%
data_ger.loc[28281:28286,["date"]]
# Out:
#              date
# 28281  2021-04-03
# 28282  2021-04-04
# 28283  2021-04-05
# 28284  2021-04-06
# 28285  2021-04-07
# 28286  2021-04-08

# %%
data_ger_relevant = data_ger[["total_cases", "new_cases", "date", "total_deaths", "new_deaths", "female_smokers", "male_smokers"]]

# %%
data_ger_relevant.groupby("date").sum()
# Out:
#             total_cases  new_cases  total_deaths  new_deaths  female_smokers  \
# date
# 2020-01-27          1.0        1.0           0.0         0.0            28.2
# 2020-01-28          4.0        3.0           0.0         0.0            28.2
# 2020-01-29          4.0        0.0           0.0         0.0            28.2
# 2020-01-30          4.0        0.0           0.0         0.0            28.2
# 2020-01-31          5.0        1.0           0.0         0.0            28.2
# ...                 ...        ...           ...         ...             ...
# 2021-04-04    2896329.0    10300.0       77060.0        50.0            28.2
# 2021-04-05    2902309.0     5980.0       77136.0        76.0            28.2
# 2021-04-06    2909902.0     7593.0       77245.0       109.0            28.2
# 2021-04-07    2940279.0    30377.0       77755.0       510.0            28.2
# 2021-04-08    2966789.0    26510.0       78049.0       294.0            28.2
#
#             male_smokers
# date
# ...

# %%
data_ger_deaths = data_ger.groupby("total_deaths")


# data_ger[["date", "total_deaths", "new_deaths"]]

# %%
data_ger_deaths.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 27849      DEU    Europe  Germany  2020-01-27          1.0        1.0
# 27850      DEU    Europe  Germany  2020-01-28          4.0        3.0
# 27851      DEU    Europe  Germany  2020-01-29          4.0        0.0
# 27852      DEU    Europe  Germany  2020-01-30          4.0        0.0
# 27853      DEU    Europe  Germany  2020-01-31          5.0        1.0
# ...        ...       ...      ...         ...          ...        ...
# 28282      DEU    Europe  Germany  2021-04-04    2896329.0    10300.0
# 28283      DEU    Europe  Germany  2021-04-05    2902309.0     5980.0
# 28284      DEU    Europe  Germany  2021-04-06    2909902.0     7593.0
# 28285      DEU    Europe  Germany  2021-04-07    2940279.0    30377.0
# 28286      DEU    Europe  Germany  2021-04-08    2966789.0    26510.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
data_ger_by_date = data_ger_relevant.groupby("date").sum()

# %%
data_ger_by_date.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # Data by Country

# %%
data_by_country = df.groupby("iso_code").count()

# %%
data_by_country
# Out:
#           continent  location  date  total_cases  new_cases  \
# iso_code
# AFG             410       410   410          410        410
# AGO             385       385   385          385        385
# AIA              44        44    44            0          0
# ALB             409       409   409          396        396
# AND             403       403   403          403        403
# ...             ...       ...   ...          ...        ...
# WSM             142       142   142          142        142
# YEM             364       364   364          364        364
# ZAF             427       427   427          400        400
# ZMB             387       387   387          387        387
# ZWE             385       385   385          385        385
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# AFG                      405           383         383                  405
# ...

# %%
data_by_country.head()
# Out:
#           continent  location  date  total_cases  new_cases  \
# iso_code
# AFG             410       410   410          410        410
# AGO             385       385   385          385        385
# AIA              44        44    44            0          0
# ALB             409       409   409          396        396
# AND             403       403   403          403        403
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# AFG                      405           383         383                  405
# AGO                      380           376         376                  380
# AIA                        0             0           0                    0
# ALB                      391           394         394                  391
# AND                      398           383         383                  398
#
#           total_cases_per_million  ...  gdp_per_capita  extreme_poverty  \
# iso_code                           ...
# ...
